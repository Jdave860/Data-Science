# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
np.random.seed(500)

# %%
df_train = pd.read_csv('train.tsv',delimiter='\t')

# %%
# Data Cleaning on Train Data
# Splitting the text from title, body and urls
boilerplate_title = df_train["boilerplate"].str.split('"title":"', n = 1, expand = True)
boilerplate_title = boilerplate_title[1].str.split('"body":"', n = 1, expand = True)
boilerplate_body = boilerplate_title[1].str.split('"url":"', n = 1, expand = True)

# %%
df_train['boilerplate_title'] = boilerplate_title[0]
df_train['boilerplate_body'] = boilerplate_body[0]
df_train['boilerplate_urls'] = boilerplate_body[1]

# %%
df_train['boilerplate_title'] = df_train['boilerplate_title'].astype(str)
df_train['boilerplate_body'] = df_train['boilerplate_body'].astype(str)
df_train['boilerplate_urls'] = df_train['boilerplate_urls'].astype(str)

# %%
df_train['boilerplate_title'] = df_train['boilerplate_title'].str.replace('[^\w\s]','')
df_train['boilerplate_body'] = df_train['boilerplate_body'].str.replace('[^\w\s]','')
df_train['boilerplate_urls'] = df_train['boilerplate_urls'].str.replace('[^\w\s]','')

# %%
data = pd.DataFrame(list(zip(df_train['boilerplate_title'], df_train['boilerplate_body'],df_train['boilerplate_urls'],df_train['label'])), 
               columns =['Title', 'Body','Url','label'])

# %%
data
# Out:
#                                                   Title  \
# 0     IBM Sees Holographic Calls Air Breathing Batte...
# 1     The Fully Electronic Futuristic Starting Gun T...
# 2     Fruits that Fight the Flu fruits that fight th...
# 3                   10 Foolproof Tips for Better Sleep
# 4     The 50 Coolest Jerseys You Didn t Know Existed...
# ...                                                 ...
# 7390  Kno Raises 46 Million More To Build Most Power...
# 7391                                Why I Miss College
# 7392  Sweet Potatoes Eat This Not That  im eating th...
# 7393                                    Naturally Ella
# 7394  Esti Ginzburg Swimsuit by Letarte by Lisa Cabr...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
# [7395 rows x 4 columns]

# %%
# Remove blank rows if any.
data = data.dropna()
data
# Out:
#                                                   Title  \
# 0     IBM Sees Holographic Calls Air Breathing Batte...
# 1     The Fully Electronic Futuristic Starting Gun T...
# 2     Fruits that Fight the Flu fruits that fight th...
# 3                   10 Foolproof Tips for Better Sleep
# 4     The 50 Coolest Jerseys You Didn t Know Existed...
# ...                                                 ...
# 7390  Kno Raises 46 Million More To Build Most Power...
# 7391                                Why I Miss College
# 7392  Sweet Potatoes Eat This Not That  im eating th...
# 7393                                    Naturally Ella
# 7394  Esti Ginzburg Swimsuit by Letarte by Lisa Cabr...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
# [7395 rows x 4 columns]

# %%
# We are extracting Title only. We will later extract Body and url to check if it helps in the accuracy of model.
# We are not taking it hear to decrease the overfitting of the model.
# Data Cleaning of train data set
# Change all the text to lower case.
data['Title'] = [entry.lower() for entry in data['Title']]

# %%
# Tokenization : In this each entry will be broken into set of words
data['Title']= [word_tokenize(entry) for entry in data['Title']]

# %%
data
# Out:
#                                                   Title  \
# 0     [ibm, sees, holographic, calls, air, breathing...
# 1     [the, fully, electronic, futuristic, starting,...
# 2     [fruits, that, fight, the, flu, fruits, that, ...
# 3             [10, foolproof, tips, for, better, sleep]
# 4     [the, 50, coolest, jerseys, you, didn, t, know...
# ...                                                 ...
# 7390  [kno, raises, 46, million, more, to, build, mo...
# 7391                            [why, i, miss, college]
# 7392  [sweet, potatoes, eat, this, not, that, im, ea...
# 7393                                  [naturally, ella]
# 7394  [esti, ginzburg, swimsuit, by, letarte, by, li...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
# [7395 rows x 4 columns]

# %%
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

# %%
# Lemmatizing train Data
for index,entry in enumerate(data['Title']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    data.loc[index,'Title_final'] = str(Final_words)

# %%
data
# Out:
#                                                   Title  \
# 0     [ibm, sees, holographic, calls, air, breathing...
# 1     [the, fully, electronic, futuristic, starting,...
# 2     [fruits, that, fight, the, flu, fruits, that, ...
# 3             [10, foolproof, tips, for, better, sleep]
# 4     [the, 50, coolest, jerseys, you, didn, t, know...
# ...                                                 ...
# 7390  [kno, raises, 46, million, more, to, build, mo...
# 7391                            [why, i, miss, college]
# 7392  [sweet, potatoes, eat, this, not, that, im, ea...
# 7393                                  [naturally, ella]
# 7394  [esti, ginzburg, swimsuit, by, letarte, by, li...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label  \
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
#                                             Title_final
# 0     ['ibm', 'see', 'holographic', 'call', 'air', '...
# 1     ['fully', 'electronic', 'futuristic', 'start',...
# 2     ['fruit', 'fight', 'flu', 'fruit', 'fight', 'f...
# 3                 ['foolproof', 'tip', 'good', 'sleep']
# 4     ['cool', 'jersey', 'know', 'exist', 'cool', 'j...
# ...                                                 ...
# 7390  ['kno', 'raise', 'million', 'build', 'powerful...
# 7391                                ['miss', 'college']
# 7392            ['sweet', 'potato', 'eat', 'im', 'eat']
# 7393                              ['naturally', 'ella']
# 7394  ['esti', 'ginzburg', 'swimsuit', 'letarte', 'l...
#
# [7395 rows x 5 columns]

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(data['Title_final'],data['label'],test_size=0.3)

# %%
Tfidf_vect = TfidfVectorizer(max_features=10000)
Tfidf_vect.fit(data['Title_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
print(Tfidf_vect.vocabulary_)
# Out:
# {'ibm': 3920, 'see': 7109, 'holographic': 3797, 'call': 1168, 'air': 131, 'breathe': 995, 'battery': 628, 'airbreathing': 133, 'fully': 3206, 'electronic': 2548, 'futuristic': 3227, 'start': 7666, 'gun': 3544, 'eliminate': 2556, 'advantage': 94, 'race': 6537, 'fruit': 3185, 'fight': 2932, 'flu': 3029, 'cold': 1602, 'mens': 5088, 'health': 3655, 'foolproof': 3073, 'tip': 8247, 'good': 3412, 'sleep': 7385, 'cool': 1764, 'jersey': 4266, 'know': 4468, 'exist': 2734, 'havent': 3636, 'genital': 3311, 'herpes': 3728, 'treatment': 8382, 'fashion': 2841, 'lane': 4544, 'american': 233, 'wild': 8909, 'child': 1415, 'recovery': 6642, 'dean': 2049, 'johnson': 4299, 'insidershealthcom': 4081, 'valet': 8617, 'handbook': 3591, 'day': 2035, 'cooky': 1763, 'cream': 1858, 'brownie': 1047, 'sweet': 7937, 'business': 1113, 'financial': 2949, 'news': 5512, 'break': 983, 'international': 4125, 'cap': 1215, 'great': 3472, 'iron': 4171, 'man': 4901, 'food': 3059, 'trash': 8371, 'teeth': 8091, 'french': 3158, 'onion': 5741, 'steak': 7681, 'red': 6650, 'wine': 8929, 'sauce': 7005, 'izabel': 4201, 'goulart': 3431, 'swimsuit': 7945, 'kikidoll': 4421, 'sport': 7606, 'illustrate': 3965, 'photo': 6094, 'gallery': 3247, 'model': 5247, 'edition': 2506, 'sicom': 7286, 'si': 7281, 'liquid': 4713, 'mountaineer': 5333, 'awesomer': 516, 'none': 5592, 'grilled': 3486, 'peach': 5988, 'sugarcrafter': 7822, 'make': 4884, 'home': 3805, 'healthier': 3662, 'room': 6874, 'guide': 3530, 'olympic': 5724, 'soccer': 7476, 'babe': 523, 'alex': 168, 'morgan': 5306, 'medal': 5049, 'win': 8923, 'bikini': 746, 'body': 861, 'bbc': 638, 'recipe': 6628, 'blueberry': 845, 'lemon': 4633, 'traybake': 8376, 'quit': 6528, 'smoking': 7439, 'counter': 1814, 'online': 5742, 'measure': 5039, 'smoke': 7435, 'cessation': 1327, 'length': 4635, 'time': 8234, 'person': 6051, 'stop': 7732, 'money': 5278, 'save': 7010, 'extra': 2766, 'live': 4724, 'gain': 3240, 'original': 5791, 'technique': 8072, 'tie': 8222, 'shoe': 7234, 'lace': 4515, 'best': 710, 'college': 1617, 'football': 3077, 'fan': 2826, 'sign': 7293, 'ever': 2699, 'alabama': 152, 'blog': 822, 'alton': 210, 'brown': 1045, 'flower': 3026, 'pot': 6303, 'smoker': 7437, 'supermodel': 7873, 'show': 7260, 'bod': 860, 'humor': 3891, 'genevieve': 3309, 'morton': 5314, 'tyler': 8482, 'rise': 6818, 'swimwear': 7946, 'homemade': 3808, 'bagel': 551, 'tammy': 8010, 'whole': 8885, 'wheat': 8866, 'chocolate': 1440, 'chai': 1332, 'muffins': 5363, 'savvy': 7016, 'eats': 2476, 'ten': 8105, 'way': 8810, 'fabulous': 2789, 'asian': 414, 'orange': 5771, 'chicken': 1409, 'allrecipes': 194, 'com': 1633, 'allrecipescom': 195, 'bread': 980, 'pudding': 6460, 'walnut': 8766, 'chip': 1430, 'epicurious': 2640, 'epicuriouscom': 2641, 'nerdsmagazine': 5491, 'everything': 2708, 'android': 263, 'microwave': 5142, 'popcorn': 6270, 'minus': 5199, 'ripoff': 6817, 'pogo': 6234, 'collegehumor': 1618, 'video': 8676, 'creamy': 1860, 'raspberry': 6591, 'popsicle': 6274, 'peta': 6061, 'org': 5783, 'raspberryorange': 6592, 'doctor': 2309, 'strike': 7770, 'mutate': 5401, 'bacteria': 541, 'teen': 8086, 'acne': 49, 'battle': 629, 'shot': 7254, 'npr': 5622, 'bottled': 938, 'water': 8798, 'fad': 2801, 'uk': 8499, 'canarygirl': 1198, 'pickle': 6122, 'ho': 3777, 'think': 8183, 'like': 4685, 'festive': 2910, 'funky': 3218, 'holiday': 3789, 'nail': 5420, 'art': 399, 'diys': 2297, 'power': 6315, 'low': 4804, 'cholesterol': 1449, 'high': 3743, 'center': 1317, 'everyday': 2705, 'alyssa': 212, 'miller': 5168, 'charlie': 1362, 'matthew': 5006, 'zink': 9115, 'maui': 5008, 'action': 58, 'headline': 3649, 'apple': 342, 'dumpling': 2431, 'ii': 3952, 'footballer': 3078, 'danous': 2011, 'estenor': 2679, 'lift': 4678, 'car': 1227, 'life': 4669, 'trapped': 8370, 'truck': 8425, 'driver': 2389, 'pro': 6386, 'athlete': 440, 'go': 3393, 'baur': 631, 'expensive': 2744, 'jean': 4238, 'world': 8986, 'more': 5303, 'recipes': 6631, 'yummymummyclub': 9083, 'ca': 1142, 'national': 5450, 'foundation': 3117, 'informat ...

# %%
print(Train_X_Tfidf)
# Out:
#   (0, 6129)	0.3323042528348102
#   (0, 5612)	0.5181133165537822
#   (0, 3601)	0.4338345277550159
#   (0, 2699)	0.35554033381477673
#   (0, 1764)	0.36704516782889446
#   (0, 221)	0.41447435757771184
#   (1, 6202)	0.12426580310779613
#   (1, 6016)	0.12034383467016178
#   (1, 3332)	0.14381620001849052
#   (1, 3331)	0.28763240003698104
#   (1, 3330)	0.43144860005547153
#   (1, 522)	0.8249315003115328
#   (2, 1588)	0.8146487700601522
#   (2, 594)	0.5799546373980309
#   (3, 7591)	0.37360575898654413
#   (3, 6859)	0.508362353478535
#   (3, 5929)	0.5317586384963808
#   (3, 1409)	0.27818864477026
#   (3, 187)	0.49176242508269646
#   (4, 6628)	0.2449110370849363
#   (4, 5499)	0.44296039441508595
#   (4, 3059)	0.31456919495765395
#   (4, 2523)	0.47439043379081375
#   (4, 2263)	0.5243553283095872
#   (4, 1749)	0.3805996590623993
#   :	:
#   (5169, 1311)	0.2099819585040761
#   (5169, 740)	0.3505993955080907
#   (5169, 511)	0.4368941717151706
#   (5171, 1633)	0.39935620166197816
#   (5171, 1173)	0.9167958465187969
#   (5172, 8367)	0.4946613852729461
#   (5172, 8075)	0.2805453608958042
#   (5172, 6052)	0.3902110941594186
#   (5172, 3226)	0.3197770865104721
#   (5172, 2578)	0.44547780208677196
#   (5172, 1646)	0.4728973030007837
#   (5173, 6152)	0.5290731352980237
#   (5173, 4884)	0.29421433077796433
#   (5173, 3026)	0.5393154047031183
#   (5173, 2381)	0.5853703437318167
#   (5174, 7305)	0.779102694995943
#   (5174, 6628)	0.20178915363619135
#   (5174, 6611)	0.40737911103209073
#   (5174, 3059)	0.2591824866941748
#   (5174, 2470)	0.34517651514924313
#   (5175, 5989)	0.35538446888052294
#   (5175, 5276)	0.49345627751283583
#   (5175, 1828)	0.44532212426387735
#   (5175, 1440)	0.5636679362624674
#   (5175, 1123)	0.3378896931431951

# %%
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print('Naive Bayes Accuracy Score: ',accuracy_score(predictions_NB, Test_Y)*100)
print('Precision score: ', precision_score(predictions_NB, Test_Y)*100)
print('Recall score: ', recall_score(predictions_NB, Test_Y)*100)
print('Cross validation score for Naive Bayes: ', Naive.score(Test_X_Tfidf, predictions_NB))
# Out:
# Naive Bayes Accuracy Score:  75.84497521406038
# Precision score:  80.35242290748899
# Recall score:  74.44897959183675
# Cross validation score for Naive Bayes:  1.0

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
print('Precision score: ', precision_score(predictions_SVM, Test_Y)*100)
print('Recall score: ', recall_score(predictions_SVM, Test_Y)*100)
print('Cross validation score for SVM: ', SVM.score(Test_X_Tfidf, predictions_NB))
# Out:
# SVM Accuracy Score ->  76.56602073005858
# Precision score:  68.98678414096916
# Recall score:  82.33438485804416
# Cross validation score for SVM:  0.8548895899053628

# %%
data_results = pd.DataFrame(list(predictions_SVM),columns=["Results"])

# %%
data_results
# Out:
#       Results
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
# ...       ...
# 2214        0
# 2215        1
# 2216        0
# 2217        1
# 2218        0
#
# [2219 rows x 1 columns]

# %%
data.to_csv("data_results.csv")
