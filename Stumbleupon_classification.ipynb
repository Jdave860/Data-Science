# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
np.random.seed(500)

# %%
df_train = pd.read_csv('train.tsv',delimiter='\t')
df_test = pd.read_csv('test.tsv',delimiter='\t')

# %%
# Data Cleaning on Train Data
# Splitting the text from title, body and urls
boilerplate_title = df_train["boilerplate"].str.split('"title":"', n = 1, expand = True)
boilerplate_title = boilerplate_title[1].str.split('"body":"', n = 1, expand = True)
boilerplate_body = boilerplate_title[1].str.split('"url":"', n = 1, expand = True)

# %%
df_train['boilerplate_title'] = boilerplate_title[0]
df_train['boilerplate_body'] = boilerplate_body[0]
df_train['boilerplate_urls'] = boilerplate_body[1]

# %%
df_train['boilerplate_title'] = df_train['boilerplate_title'].astype(str)
df_train['boilerplate_body'] = df_train['boilerplate_body'].astype(str)
df_train['boilerplate_urls'] = df_train['boilerplate_urls'].astype(str)

# %%
df_train['boilerplate_title'] = df_train['boilerplate_title'].str.replace('[^\w\s]','')
df_train['boilerplate_body'] = df_train['boilerplate_body'].str.replace('[^\w\s]','')
df_train['boilerplate_urls'] = df_train['boilerplate_urls'].str.replace('[^\w\s]','')

# %%
data = pd.DataFrame(list(zip(df_train['boilerplate_title'], df_train['boilerplate_body'],df_train['boilerplate_urls'],df_train['label'])), 
               columns =['Title', 'Body','Url','label'])

# %%
data
# Out:
#                                                   Title  \
# 0     IBM Sees Holographic Calls Air Breathing Batte...
# 1     The Fully Electronic Futuristic Starting Gun T...
# 2     Fruits that Fight the Flu fruits that fight th...
# 3                   10 Foolproof Tips for Better Sleep
# 4     The 50 Coolest Jerseys You Didn t Know Existed...
# ...                                                 ...
# 7390  Kno Raises 46 Million More To Build Most Power...
# 7391                                Why I Miss College
# 7392  Sweet Potatoes Eat This Not That  im eating th...
# 7393                                    Naturally Ella
# 7394  Esti Ginzburg Swimsuit by Letarte by Lisa Cabr...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
# [7395 rows x 4 columns]

# %%
# Remove blank rows if any.
data = data.dropna()
data
# Out:
#                                                   Title  \
# 0     ibm sees holographic calls air breathing batte...
# 1     the fully electronic futuristic starting gun t...
# 2     fruits that fight the flu fruits that fight th...
# 3                   10 foolproof tips for better sleep
# 4     the 50 coolest jerseys you didn t know existed...
# ...                                                 ...
# 7390  kno raises 46 million more to build most power...
# 7391                                why i miss college
# 7392  sweet potatoes eat this not that  im eating th...
# 7393                                    naturally ella
# 7394  esti ginzburg swimsuit by letarte by lisa cabr...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
# [7395 rows x 4 columns]

# %%
# We are extracting Title only. We will later extract Body and url to check if it helps in the accuracy of model.
# We are not taking it hear to decrease the overfitting of the model.
# Data Cleaning of train data set
# Change all the text to lower case.
data['Title'] = [entry.lower() for entry in data['Title']]

# %%
# Tokenization : In this each entry will be broken into set of words
data['Title']= [word_tokenize(entry) for entry in data['Title']]

# %%
data
# Out:
#                                                   Title  \
# 0     [ibm, sees, holographic, calls, air, breathing...
# 1     [the, fully, electronic, futuristic, starting,...
# 2     [fruits, that, fight, the, flu, fruits, that, ...
# 3             [10, foolproof, tips, for, better, sleep]
# 4     [the, 50, coolest, jerseys, you, didn, t, know...
# ...                                                 ...
# 7390  [kno, raises, 46, million, more, to, build, mo...
# 7391                            [why, i, miss, college]
# 7392  [sweet, potatoes, eat, this, not, that, im, ea...
# 7393                                  [naturally, ella]
# 7394  [esti, ginzburg, swimsuit, by, letarte, by, li...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
# [7395 rows x 4 columns]

# %%
# Data cleaning on Test Data
# Splitting the text from title, body and urls
boilerplatetest_title = df_test["boilerplate"].str.split('"title":"', n = 1, expand = True)
boilerplatetest_title = boilerplatetest_title[1].str.split('"body":"', n = 1, expand = True)
boilerplatetest_body = boilerplatetest_title[1].str.split('"url":"', n = 1, expand = True)

# %%
df_test['boilerplate_title'] = boilerplatetest_title[0]
df_test['boilerplate_body'] = boilerplatetest_body[0]
df_test['boilerplate_urls'] = boilerplatetest_body[1]

# %%
df_test['boilerplate_title'] = df_test['boilerplate_title'].astype(str)
df_test['boilerplate_body'] = df_test['boilerplate_body'].astype(str)
df_test['boilerplate_urls'] = df_test['boilerplate_urls'].astype(str)

# %%
df_test['boilerplate_title'] = df_test['boilerplate_title'].str.replace('[^\w\s]','')
df_test['boilerplate_body'] = df_test['boilerplate_body'].str.replace('[^\w\s]','')
df_test['boilerplate_urls'] = df_test['boilerplate_urls'].str.replace('[^\w\s]','')

# %%
dataTest = pd.DataFrame(list(zip(df_test['boilerplate_title'], df_test['boilerplate_body'],df_test['boilerplate_urls'])), 
               columns =['Title', 'Body','Url'])

# %%
dataTest
# Out:
#                                                   Title  \
# 0     Homemade Enchilada Sauce Lynn s Kitchen Advent...
# 1                              lolpics Stun grenade ar
# 2                                           Treadmills
# 3     Father s Tactics Used by Assad to Crush Revolt...
# 4     Stem Turns Lemons and Limes Into Juicy Atomize...
# ...                                                 ...
# 3166  Peep Brownie S mores Busy Mommy An Iowa Mom Blog
# 3167  Marijuana infused cheesecake Medical Cannabis ...
# 3168  Most Viewed Submissions All Time most viewed s...
# 3169  How to Get a Complete Workout with Nothing But...
# 3170  Crispy Parmesan Asparagus Sticks How Sweet It Is
#
#                                                    Body  \
# 0     I usually buy my enchilada sauce Yes I knew I ...
# 1      funny pictures at lolpicsse the best funny im...
# 2                  treadmills stair climbers treadmills
# 3     Enlarge image Syrian President Bashar al Assad...
# 4     Quirky s Stem turns any citrus fruit into an a...
# ...                                                 ...
# 3166  Easter candy is hitting the shelves and I ve b...
# 3167  Cannabis infused cheesecake is one of the tast...
# 3168  www tastespotting com January 27 is National C...
# 3169  Everyone knows exercise plays an important rol...
# 3170  Who would have ever thought I would get excite...
#
#                                                     Url
# 0     lynnskitchenadventures 2009 04 homemade enchil...
# 1                      lolpics se 18552 stun grenade ar
# 2                    xcelerationfitness treadmills html
# 3     bloomberg news 2012 02 06 syria s assad deploy...
# 4     wired gadgetlab 2011 12 stem turns lemons and ...
# ...                                                 ...
# 3166        busy mommy 2012 02 peep brownie smores html
# 3167                                               None
# 3168             tastespotting popular views all time 2
# 3169  lifehacker 5839197 how to get a full body work...
# 3170  howsweeteats 2011 03 crispy parmesan asparagus...
#
# [3171 rows x 3 columns]

# %%
# Remove blank rows if any.
dataTest = dataTest.dropna()
dataTest
# Out:
#                                                   Title  \
# 0     Homemade Enchilada Sauce Lynn s Kitchen Advent...
# 1                              lolpics Stun grenade ar
# 2                                           Treadmills
# 3     Father s Tactics Used by Assad to Crush Revolt...
# 4     Stem Turns Lemons and Limes Into Juicy Atomize...
# ...                                                 ...
# 3166  Peep Brownie S mores Busy Mommy An Iowa Mom Blog
# 3167  Marijuana infused cheesecake Medical Cannabis ...
# 3168  Most Viewed Submissions All Time most viewed s...
# 3169  How to Get a Complete Workout with Nothing But...
# 3170  Crispy Parmesan Asparagus Sticks How Sweet It Is
#
#                                                    Body  \
# 0     I usually buy my enchilada sauce Yes I knew I ...
# 1      funny pictures at lolpicsse the best funny im...
# 2                  treadmills stair climbers treadmills
# 3     Enlarge image Syrian President Bashar al Assad...
# 4     Quirky s Stem turns any citrus fruit into an a...
# ...                                                 ...
# 3166  Easter candy is hitting the shelves and I ve b...
# 3167  Cannabis infused cheesecake is one of the tast...
# 3168  www tastespotting com January 27 is National C...
# 3169  Everyone knows exercise plays an important rol...
# 3170  Who would have ever thought I would get excite...
#
#                                                     Url
# 0     lynnskitchenadventures 2009 04 homemade enchil...
# 1                      lolpics se 18552 stun grenade ar
# 2                    xcelerationfitness treadmills html
# 3     bloomberg news 2012 02 06 syria s assad deploy...
# 4     wired gadgetlab 2011 12 stem turns lemons and ...
# ...                                                 ...
# 3166        busy mommy 2012 02 peep brownie smores html
# 3167                                               None
# 3168             tastespotting popular views all time 2
# 3169  lifehacker 5839197 how to get a full body work...
# 3170  howsweeteats 2011 03 crispy parmesan asparagus...
#
# [3171 rows x 3 columns]

# %%
# Change all the text to lower case.
dataTest['Title'] = [entry.lower() for entry in dataTest['Title']]

# %%
#Tokenization : In this each entry will be broken into set of words
dataTest['Title']= [word_tokenize(entry) for entry in dataTest['Title']]

# %%
dataTest
# Out:
#                                                   Title  \
# 0     [homemade, enchilada, sauce, lynn, s, kitchen,...
# 1                          [lolpics, stun, grenade, ar]
# 2                                          [treadmills]
# 3     [father, s, tactics, used, by, assad, to, crus...
# 4     [stem, turns, lemons, and, limes, into, juicy,...
# ...                                                 ...
# 3166  [peep, brownie, s, mores, busy, mommy, an, iow...
# 3167  [marijuana, infused, cheesecake, medical, cann...
# 3168  [most, viewed, submissions, all, time, most, v...
# 3169  [how, to, get, a, complete, workout, with, not...
# 3170  [crispy, parmesan, asparagus, sticks, how, swe...
#
#                                                    Body  \
# 0     I usually buy my enchilada sauce Yes I knew I ...
# 1      funny pictures at lolpicsse the best funny im...
# 2                  treadmills stair climbers treadmills
# 3     Enlarge image Syrian President Bashar al Assad...
# 4     Quirky s Stem turns any citrus fruit into an a...
# ...                                                 ...
# 3166  Easter candy is hitting the shelves and I ve b...
# 3167  Cannabis infused cheesecake is one of the tast...
# 3168  www tastespotting com January 27 is National C...
# 3169  Everyone knows exercise plays an important rol...
# 3170  Who would have ever thought I would get excite...
#
#                                                     Url
# 0     lynnskitchenadventures 2009 04 homemade enchil...
# 1                      lolpics se 18552 stun grenade ar
# 2                    xcelerationfitness treadmills html
# 3     bloomberg news 2012 02 06 syria s assad deploy...
# 4     wired gadgetlab 2011 12 stem turns lemons and ...
# ...                                                 ...
# 3166        busy mommy 2012 02 peep brownie smores html
# 3167                                               None
# 3168             tastespotting popular views all time 2
# 3169  lifehacker 5839197 how to get a full body work...
# 3170  howsweeteats 2011 03 crispy parmesan asparagus...
#
# [3171 rows x 3 columns]

# %%
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

# %%
# Lemmatizing train Data
for index,entry in enumerate(data['Title']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    data.loc[index,'Title_final'] = str(Final_words)

# %%
data
# Out:
#                                                   Title  \
# 0     [ibm, sees, holographic, calls, air, breathing...
# 1     [the, fully, electronic, futuristic, starting,...
# 2     [fruits, that, fight, the, flu, fruits, that, ...
# 3             [10, foolproof, tips, for, better, sleep]
# 4     [the, 50, coolest, jerseys, you, didn, t, know...
# ...                                                 ...
# 7390  [kno, raises, 46, million, more, to, build, mo...
# 7391                            [why, i, miss, college]
# 7392  [sweet, potatoes, eat, this, not, that, im, ea...
# 7393                                  [naturally, ella]
# 7394  [esti, ginzburg, swimsuit, by, letarte, by, li...
#
#                                                    Body  \
# 0     A sign stands outside the International Busine...
# 1     And that can be carried on a plane without the...
# 2     Apples The most popular source of antioxidants...
# 3     There was a period in my life when I had a lot...
# 4     Jersey sales is a curious business Whether you...
# ...                                                 ...
# 7390  Marc Andreessen is normally enthusiastic about...
# 7391  Mar 30 2009 I d like to congratulate Jane on h...
# 7392  They re loaded with vitamin C which smoothes o...
# 7393
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
#                                                     Url  label  \
# 0     bloomberg news 2010 12 23 ibm predicts hologra...      0
# 1     popsci technology article 2012 07 electronic f...      1
# 2     menshealth health flu fighting fruits cm mmc F...      1
# 3     dumblittleman 2007 12 10 foolproof tips for be...      1
# 4     bleacherreport articles 1205138 the 50 coolest...      0
# ...                                                 ...    ...
# 7390  techcrunch 2010 09 08 kno raises 46 million mo...      0
# 7391              uncoached category why i miss college      0
# 7392  eatthis menshealth slide sweet potatoes slides...      1
# 7393                                      naturallyella      1
# 7394  sportsillustrated cnn 2011 swimsuit models est...      0
#
#                                             Title_final
# 0     ['ibm', 'see', 'holographic', 'call', 'air', '...
# 1     ['fully', 'electronic', 'futuristic', 'start',...
# 2     ['fruit', 'fight', 'flu', 'fruit', 'fight', 'f...
# 3                 ['foolproof', 'tip', 'good', 'sleep']
# 4     ['cool', 'jersey', 'know', 'exist', 'cool', 'j...
# ...                                                 ...
# 7390  ['kno', 'raise', 'million', 'build', 'powerful...
# 7391                                ['miss', 'college']
# 7392            ['sweet', 'potato', 'eat', 'im', 'eat']
# 7393                              ['naturally', 'ella']
# 7394  ['esti', 'ginzburg', 'swimsuit', 'letarte', 'l...
#
# [7395 rows x 5 columns]

# %%
#Lemmatizing test data
for index,entry in enumerate(dataTest['Title']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    dataTest.loc[index,'Title_final'] = str(Final_words)

# %%
dataTest
# Out:
#                                                   Title  \
# 0     [homemade, enchilada, sauce, lynn, s, kitchen,...
# 1                          [lolpics, stun, grenade, ar]
# 2                                          [treadmills]
# 3     [father, s, tactics, used, by, assad, to, crus...
# 4     [stem, turns, lemons, and, limes, into, juicy,...
# ...                                                 ...
# 3166  [peep, brownie, s, mores, busy, mommy, an, iow...
# 3167  [marijuana, infused, cheesecake, medical, cann...
# 3168  [most, viewed, submissions, all, time, most, v...
# 3169  [how, to, get, a, complete, workout, with, not...
# 3170  [crispy, parmesan, asparagus, sticks, how, swe...
#
#                                                    Body  \
# 0     I usually buy my enchilada sauce Yes I knew I ...
# 1      funny pictures at lolpicsse the best funny im...
# 2                  treadmills stair climbers treadmills
# 3     Enlarge image Syrian President Bashar al Assad...
# 4     Quirky s Stem turns any citrus fruit into an a...
# ...                                                 ...
# 3166  Easter candy is hitting the shelves and I ve b...
# 3167  Cannabis infused cheesecake is one of the tast...
# 3168  www tastespotting com January 27 is National C...
# 3169  Everyone knows exercise plays an important rol...
# 3170  Who would have ever thought I would get excite...
#
#                                                     Url  \
# 0     lynnskitchenadventures 2009 04 homemade enchil...
# 1                      lolpics se 18552 stun grenade ar
# 2                    xcelerationfitness treadmills html
# 3     bloomberg news 2012 02 06 syria s assad deploy...
# 4     wired gadgetlab 2011 12 stem turns lemons and ...
# ...                                                 ...
# 3166        busy mommy 2012 02 peep brownie smores html
# 3167                                               None
# 3168             tastespotting popular views all time 2
# 3169  lifehacker 5839197 how to get a full body work...
# 3170  howsweeteats 2011 03 crispy parmesan asparagus...
#
#                                             Title_final
# 0     ['homemade', 'enchilada', 'sauce', 'lynn', 'ki...
# 1                  ['lolpics', 'stun', 'grenade', 'ar']
# 2                                         ['treadmill']
#   (2, 301)	0.5799546373980309
#   (3, 4175)	0.4411471786107009
#   (3, 3762)	0.6002654203117588
#   (3, 759)	0.328480310621643
#   (3, 98)	0.5806645137389359
#   (4, 3630)	0.2449110370849363
#   (4, 2969)	0.44296039441508595
#   (4, 1701)	0.31456919495765395
#   (4, 1428)	0.47439043379081375
#   (4, 1274)	0.5243553283095872
#   (4, 954)	0.3805996590623993
#   (5, 4223)	0.7498095329521639
#   (5, 3817)	0.6616537344367202
#   (6, 4062)	0.5365261687753738
#   :	:
#   (5169, 1450)	0.27888438516663033
#   (5169, 1268)	0.2630542952986061
#   (5169, 707)	0.2499312284850412
#   (5169, 389)	0.41730126840277554
#   (5169, 247)	0.5200137089520835
#   (5171, 875)	1.0
#   (5172, 4473)	0.3228051401443184
#   (5172, 3283)	0.4489903042195799
#   (5172, 1790)	0.36794651280757856
#   (5172, 1460)	0.5125820789715794
#   (5172, 886)	0.5441318996742721
#   (5173, 3345)	0.5290731352980237
#   (5173, 2601)	0.29421433077796433
#   (5173, 1677)	0.5393154047031183
#   (5173, 1341)	0.5853703437318167
#   (5174, 3981)	0.779102694995943
#   (5174, 3630)	0.20178915363619135
#   (5174, 3621)	0.40737911103209073
#   (5174, 1701)	0.2591824866941748
#   (5174, 1397)	0.34517651514924313
#   (5175, 3242)	0.35538446888052294
#   (5175, 2837)	0.49345627751283583
#   (5175, 1011)	0.44532212426387735
#   (5175, 777)	0.5636679362624674
#   (5175, 612)	0.3378896931431951

# %%
# # seperate the independent and target variable on training data
# Train_X = data['Title_final']
# Train_Y = data['label']

# # independent variable on testing data
# Test_X = dataTest['Title_final']

# %%
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print('Naive Bayes Accuracy Score: ',accuracy_score(predictions_NB, Test_Y)*100)
print('Precision score: ', precision_score(predictions_NB, Test_Y)*100)
print('Recall score: ', recall_score(predictions_NB, Test_Y)*100)
print('Cross validation score for Naive Bayes: ', Naive.score(Test_X_Tfidf, predictions_NB))
# Out:
# Naive Bayes Accuracy Score:  76.25056331680938
# Precision score:  79.47136563876653
# Recall score:  75.4180602006689
# Cross validation score for Naive Bayes:  1.0

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
print('Precision score: ', precision_score(predictions_SVM, Test_Y)*100)
print('Recall score: ', recall_score(predictions_SVM, Test_Y)*100)
print('Cross validation score for SVM: ', SVM.score(Test_X_Tfidf, predictions_NB))
# Out:
# SVM Accuracy Score ->  76.92654348805769
# Precision score:  69.69162995594714
# Recall score:  82.48175182481752
# Cross validation score for SVM:  0.8589454709328527

# %%
data_results = pd.DataFrame(list(predictions_SVM),columns=["Results"])

# %%
data_results
# Out:
#       Results
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# ...       ...
# 2214        0
# 2215        1
# 2216        0
# 2217        1
# 2218        0
#
# [2219 rows x 1 columns]

# %%
data.to_csv("data_results.csv")
