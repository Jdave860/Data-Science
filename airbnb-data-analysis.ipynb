# %%
# Importing all the libraries for the project
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
# Extraction Process from csv to pandas dataframe
df = pd.read_csv("price_train.csv")
df.head()
# Out:
#      X1        id  host_is_superhost host_response_rate  host_response_time  \
# 0  5460  22146017              False                99%      within an hour
# 1  4143  18638163               True               100%      within an hour
# 2  5802  22734110               True               100%      within an hour
# 3   776   3946674               True                90%  within a few hours
# 4  6064  23610186               True               100%      within an hour
#
#    host_listings_count  host_identity_verified  accommodates  \
# 0                  521                   False             5
# 1                    1                    True             2
# 2                    1                   False             4
# 3                    1                    True             2
# 4                    4                    True             8
#
#   neighbourhood_group_cleansed property_type  ... bedrooms  beds  bed_type  \
# 0                     Downtown     Apartment  ...        2     2  Real Bed
# 1                   Queen Anne         House  ...        0     1  Real Bed
# 2               Rainier Valley   Guest suite  ...        1     2  Real Bed
# 3                 Central Area         House  ...        1     1  Real Bed
# 4                  Beacon Hill         House  ...        3     3  Real Bed
#
#                                            amenities  cleaning_fee  \
# 0  {TV,Internet,Wifi,Kitchen,Elevator,Heating,"Fa...       $129.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        $50.00
# 2  {TV,Wifi,"Air conditioning",Kitchen,"Free stre...        $25.00
# 3  {Internet,Wifi,Kitchen,"Pets live on this prop...         $0.00
# 4  {TV,Wifi,Kitchen,"Free parking on premises","S...        $99.00
#
#    minimum_nights  maximum_nights instant_bookable cancellation_policy  \
# 0               2            1125             True              strict
# 1               2              30             True            moderate
# 2               2              28            False            moderate
# 3               2              30            False            flexible
# 4               2              12            False            flexible
#
#      price
# 0  $279.00
# 1   $99.00
# 2   $75.00
# 3   $70.00
# 4  $242.00
#
# [5 rows x 25 columns]

# %%
# function to print and calculate total amenities


def total_amenities(x):
  total_amen = []
  for i in x:
    z = i.replace('{' , '')
    z = z.replace('}' , '')
    z = z.replace('"' , '').split(',')
    for j in z:
      if j not in total_amen:
        total_amen.append(j)
        print(j)

  print(len(total_amen))


total_amenities(df['amenities'])
# Out:
# TV
# Internet
# Wifi
# Kitchen
# Elevator
# Heating
# Family/kid friendly
# Washer
# Dryer
# Smoke detector
# Carbon monoxide detector
# First aid kit
# Safety card
# Fire extinguisher
# Essentials
# Shampoo
# Hangers
# Hair dryer
# Iron
# Laptop friendly workspace
# Self check-in
# Smart lock
# Keypad
# Private living room
# Cable TV
# Air conditioning
# Pets live on this property
# Free street parking
# Indoor fireplace
# translation missing: en.hosting_amenity_49
# translation missing: en.hosting_amenity_50
# Private entrance
# Hot water
# Bed linens
# Microwave
# Coffee maker
# Refrigerator
# Dishwasher
# Dishes and silverware
# Cooking basics
# Oven
# Stove
# Luggage dropoff allowed
# Full kitchen
# Room-darkening shades
# Patio or balcony
# Lock on bedroom door
# Other
# Free parking on premises
# Smoking allowed
# Breakfast
# Hot tub
# Suitable for events
# 24-hour check-in
# Extra pillows and blankets
# Garden or backyard
# Wide doorway
# Wide entryway
# Handheld shower head
# Buzzer/wireless intercom
# Pack ’n Play/travel crib
# Pool
# Pets allowed
# Gym
# Single level home
# BBQ grill
# Long term stays allowed
# Step-free access
# Flat path to front door
# Well-lit path to entrance
# Waterfront
# Paid parking on premises
# Lockbox
# Baby monitor
# Outlet covers
# Bathtub
# Baby bath
# Changing table
# High chair
# Children’s books and toys
# Children’s dinnerware
# Dog(s)
# Other pet(s)
# Accessible-height toilet
# Paid parking off premises
# Body soap
# Bath towel
# Toilet paper
# Hot water kettle
# Smart TV
# Netflix
# Outdoor seating
# Walk-in shower
# Bedroom comforts
# Bathroom essentials
# Building staff
# Babysitter recommendations
# Pocket wifi
# Host greets you
# Beach essentials
# Wide hallway clearance
# Wide clearance to bed
# Accessible-height bed
# Mountain view
# Balcony
# Gas oven
# Formal dining area
# Memory foam mattress
# Warming drawer
# Cleaning before checkout
# Fireplace guards
# Ethernet connection
# Wheelchair accessible
# Doorman
# Cat(s)
# Lake access
# Crib
# EV charger
# Game console
# Kitchenette
# Breakfast table
# Espresso machine
# Fixed grab bars for shower
# Stair gates
# Beachfront
# Central air conditioning
# Rain shower
# Disabled parking spot
# Wide clearance to shower
#  toilet
# Fixed grab bars for toilet
# Roll-in shower
# Sound system
# Amazon Echo
# Heated floors
# High-resolution computer monitor
# Ceiling fan
# Jetted tub
# Electric profiling bed
# Terrace
# En suite bathroom
# Firm mattress
# DVD player
# Beach view
# Fire pit
# Day bed
# Private hot tub
# Private bathroom
# Shower chair
# Mini fridge
# HBO GO
# Window guards
# Outdoor parking
# Bathtub with bath chair
# Printer
# Sun loungers
# Pool with pool hoist
# Convection oven
# Heated towel rack
# Standing valet
# Pillow-top mattress
# Soaking tub
# Exercise equipment
# Shared gym
# Shared pool
# Shared hot tub
# Table corner guards
# Wine cooler
# Sauna
# Hammock
# Stand alone steam shower
# Steam oven
# Heat lamps
#
# Mudroom
# Projector and screen
# Ground floor access
# Ski-in/Ski-out
# 178

# %%
# Univariate Analysis of each column to get to know dataset more clearly
# function to present the count plot graph
def CountPlot(x,df,xl='x-axis',yl='Total Count',title='Countplot',z=0):
  length = len(df)
  g=sns.countplot(x=x,data=df)
  for p in g.patches:
    height = p.get_height()
    g.text(p.get_x()+p.get_width()/2.,height + 20,'{:1.2f}%'.format(height/length*100),ha="center") 
  g.set(xlabel=xl, ylabel=yl, title=title)
  plt.xticks(rotation=z)
  plt.show()

# %%
# Visualizing countplot of column 'host_is_superhost'
CountPlot('host_is_superhost',df,'Host is Superhost','Total Count of Response','Count Plot of response of Host is SuperHost')

# %% [markdown]
# #### The above count plots shows that 'Host is Superhost' is false as it is about 50.84%

# %%
# Visualizing countplot of column 'host_response_time'
CountPlot('host_response_time',df,'Host Response Time','Total Count of Response','Count Plot of Host Response Time',45)

# %% [markdown]
# #### The about plot shows that the host response time is heighest with in an hour with 83.29%

# %%
# Now creating ETL pipline class which will Extract the csv data, transform into required format and then save the new dataset as csv.
class ETL:
  def __init__(self, Path,Train=True):
    self.df = pd.read_csv(Path)
    self.Train = Train
    self.Transform()
  
  # Method to Transform the data into required format

  def Transform(self):
    # Deleting X1 and id columns as they both are for identification 
    self.df = self.df.drop(['X1','id'],axis=1)

    # Function to Convert the boolean values into Numerical values
    def bool_to_num(x):
      if x==True:
        return 1
      else:
        return 0

    # Applying the bool_to_num function on 'host_is_superhost','host_identity_verified' and 'instant_bookable'
    self.df['host_is_superhost'] = self.df['host_is_superhost'].apply(bool_to_num)
    self.df['host_identity_verified'] = self.df['host_identity_verified'].apply(bool_to_num)
    self.df['instant_bookable'] = self.df['instant_bookable'].apply(bool_to_num)

    # Function to split the number and % and convert it into numerical values
    def percentage_to_num(x):
      return int(x.split('%')[0])

    # Applying the string_to_num function on 'host_response_rate'
    self.df['host_response_rate'] = self.df['host_response_rate'].apply(percentage_to_num)

    # Function to split the number and $ and convert it into numerical values
    def dollar_to_num(x):
      if x == '0':
        return float(x)
      else:
        try:
          return float(x.split('$')[1])
        except:
          return float(x.replace(',' , '').split('$')[1])

    
    # Applying the string_to_num function on 'cleaning_fee' and 'price'
    self.df['cleaning_fee'] = self.df['cleaning_fee'].apply(dollar_to_num)
    if self.Train:
      self.df['price'] = self.df['price'].apply(dollar_to_num)

    # creating instance of labelencoder
    labelencoder = LabelEncoder()

    # Assigning numerical values and storing in same column (host_response_time, neighbourhood_group_cleansed, property_type, room_type, bed_type, cancellation_policy)
    label_encoding_cols = ['host_response_time', 'neighbourhood_group_cleansed', 'property_type', 'room_type', 'bed_type', 'cancellation_policy']
    for i in label_encoding_cols:
      self.df[i] = labelencoder.fit_transform(self.df[i])


    # As there are total 178 amenities, we are creating a column in which total amenities of that entry is present.
    # Function to convert amenities column into total amenities present for that entry
    def total_amenities(x):
      total = 0
      z = x.replace('{' , '')
      z = z.replace('}' , '')
      z = z.replace('"' , '').split(',')
      for j in z:
        total = total + 1
      return total

    
    # Applying the total_amenities function on 'amenities'
    self.df['amenities'] = self.df['amenities'].apply(total_amenities)
        

      

  # Function to print and save transformed data
  def Load(self):
    self.df.to_csv("Transformed_Data.csv")
    return self.df

# %%
etl = ETL("price_train.csv")

# %%
dataset = etl.Load()
dataset.head()
# Out:
#    host_is_superhost  host_response_rate  host_response_time  \
# 0                  0                  99                   3
# 1                  1                 100                   3
# 2                  1                 100                   3
# 3                  1                  90                   2
# 4                  1                 100                   3
#
#    host_listings_count  host_identity_verified  accommodates  \
# 0                  521                       0             5
# 1                    1                       1             2
# 2                    1                       0             4
# 3                    1                       1             2
# 4                    4                       1             8
#
#    neighbourhood_group_cleansed  property_type  room_type   latitude  ...  \
# 0                             6              1          0  47.612163  ...
# 1                            12             14          0  47.640827  ...
# 2                            13             11          0  47.549007  ...
# 3                             4             14          1  47.601922  ...
# 4                             1             14          0  47.552311  ...
#
#    bedrooms  beds  bed_type  amenities  cleaning_fee  minimum_nights  \
# 0         2     2         3         24         129.0               2
# 1         0     1         3         39          50.0               2
# 2         1     2         3         32          25.0               2
# 3         1     1         3         17           0.0               2
# 4         3     3         3         30          99.0               2
#
#    maximum_nights  instant_bookable  cancellation_policy  price
# 0            1125                 1                    2  279.0
# 1              30                 1                    1   99.0
# 2              28                 0                    1   75.0
# 3              30                 0                    0   70.0
# 4              12                 0                    0  242.0
#
# [5 rows x 23 columns]

# %%
result = dataset.dtypes
result
# Out:
# host_is_superhost                 int64
# host_response_rate                int64
# host_response_time                int32
# host_listings_count               int64
# host_identity_verified            int64
# accommodates                      int64
# neighbourhood_group_cleansed      int32
# property_type                     int32
# room_type                         int32
# latitude                        float64
# longitude                       float64
# guests_included                   int64
# bathrooms                       float64
# bedrooms                          int64
# beds                              int64
# bed_type                          int32
# amenities                         int64
# cleaning_fee                    float64
# minimum_nights                    int64
# maximum_nights                    int64
# instant_bookable                  int64
# cancellation_policy               int32
# price                           float64
# dtype: object

# %%
dataset_columns = ['host_is_superhost','host_response_rate','host_response_time','host_listings_count','host_identity_verified','accommodates','neighbourhood_group_cleansed','property_type','room_type','latitude','longitude','guests_included','bathrooms','bedrooms','beds','bed_type','amenities','cleaning_fee','minimum_nights','maximum_nights','instant_bookable','cancellation_policy','price']

# %%
# To plot univariente variables
dataset.hist(bins=50,figsize=(20,15))
plt.show()

# %%
#Boxplot visualization price with respect to price variable
def box_plot(x,y):
    for i in x:
        sns.boxplot(x=i, y="price", data=y, hue=i)
        plt.show()

# %%
dataset_columns = ['host_is_superhost','host_response_time','host_identity_verified','room_type','bathrooms','bedrooms','bed_type','instant_bookable','cancellation_policy']
box_plot(dataset_columns,dataset)

# %%
#Scatterplot visualization price with respect to price variable
def scatter_plot(x,y):
    for i in x:
        sns.catplot(x=i, y="price", data=y)
        plt.show()

# %%
dataset_columns = ['host_is_superhost','host_response_time','host_identity_verified','room_type','bathrooms','bedrooms','beds','bed_type','instant_bookable','cancellation_policy']
scatter_plot(dataset_columns,dataset)

# %%
#Barplot visualization price with respect to price variable
def barplot(x,y):
    for i in x:
        sns.catplot(x=i, y="price", kind="bar", data=y)
        plt.show()

# %%
dataset_columns = ['host_is_superhost','host_response_time','host_identity_verified','room_type','bed_type','instant_bookable','cancellation_policy']
barplot(dataset_columns,dataset)

# %%
#Pie chart with respect to neighbourhood group
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15,9))
plt.title("Neighbourhood Group")
g = plt.pie(dataset.neighbourhood_group_cleansed.value_counts(), labels=df.neighbourhood_group_cleansed.value_counts().index,autopct='%1.1f%%', startangle=180)
plt.show()

# %% [markdown]
# #### The above pie chart shows that the heighest neighbourhood group of Airbnb listing is in Downtown and lowest in Interbay

# %%
#Barplot for count of Room Types
plt.figure(figsize=(13,7))
plt.title("Type of Room")
sns.countplot(df.room_type, palette="muted")
fig = plt.gcf()
plt.show()

# %% [markdown]
# #### The above plot clearly shows that there is a high demand for Entire Home/Apt followed by Private room and the shared room beign the lest preference

# %%
# price group distribution using Box plot
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group Price Distribution < 650")
sns.boxplot(y="price",x ='neighbourhood_group_cleansed' ,data = dataset[dataset.price<500])
plt.show()

# %%
#Plot for neighbourhood price  distribution with respect to price

plt.figure(figsize=(12,9))
ax=dataset[dataset.price<500].plot(kind='scatter', x='longitude',y='latitude',label='availability',title='price distribution',c='price',cmap=plt.get_cmap('jet'),colorbar=True,alpha=0.4)
ax.legend()
plt.ioff()
plt.show()

# %% [markdown]
# #### The above plot shows the red dots with heighest price and blue with lowes price

# %%
#longitude latitude with respect to price
plt.figure(figsize=(10,7), facecolor='w', edgecolor='k')
sns.scatterplot(dataset["longitude"], dataset["latitude"], hue=dataset["price"])
plt.title("Latitude to Longitude for Type of room")
# Out:
# Text(0.5, 1.0, 'Latitude to Longitude for Type of room')

# %% [markdown]
# #### The above plot shows that Airbnb has most of the room with in price range 0 to 600 dollars.

# %%
# Airbnb neighbour distribution
plt.figure(figsize=(10,7), facecolor='w', edgecolor='k')
sns.scatterplot(dataset["longitude"], dataset["latitude"], hue=df["neighbourhood_group_cleansed"])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.2)
plt.title("Lattitude to Longitude for neighbourhood region")
# Out:
# Text(0.5, 1.0, 'Lattitude to Longitude for Regionname')

# %%
#Distibution with respect to room type
plt.figure(figsize=(10,7), facecolor='w', edgecolor='k')
sns.scatterplot(dataset["longitude"], dataset["latitude"], hue=df["room_type"])
plt.title("Lattitude to Longitude for Type of room")
# Out:
# Text(0.5, 1.0, 'Lattitude to Longitude for Type of room')

# %%
#Distribution of Price vs room type with respect to Host identity verified
plt.figure(figsize=(10,7), facecolor='w', edgecolor='k')
sns.barplot(df["room_type"], dataset["price"], hue=df["host_identity_verified"])
plt.title("Price vs room type with respect to Host identity verified")
# Out:
# Text(0.5, 1.0, 'Price vs room type with respect to Host identity verified')

# %% [markdown]
# #### The above plot shows that Entire home has highest false verified host identity with respect to price and private rooms has equal verified host identity with moderate price range and shared room has more True verified host identity as compared to false host identity

# %%
#Distribution of Bed type vs bedrooms with respect to room type
plt.figure(figsize=(10,7), facecolor='w', edgecolor='k')
sns.barplot(df["bed_type"], dataset["bedrooms"], hue=df["room_type"])
plt.yticks(np.arange(0, 4, 1))
plt.title("Price vs room type with respect to instant_bookable")
# Out:
# Text(0.5, 1.0, 'Price vs room type with respect to instant_bookable')

# %% [markdown]
# #### The above graph shows that Entire home/apt has heighest number of Real Bed bedrooms, Shared room dont have any pull-out sofa where as there are equal number of air bed for all three room types

# %%
#correlation matrix
def corr(x):
    corrmat = x.corr()
    #corrmat = corrmat.filter()
    print(corrmat)
    f, ax = plt.subplots(figsize=(20, 9))
    sns.heatmap(corrmat, vmax=1,vmin=-1, square=True);
corr(dataset)
# Out:
#                               host_is_superhost  host_response_rate  \
# host_is_superhost                      1.000000            0.135312
# host_response_rate                     0.135312            1.000000
# host_response_time                     0.093204            0.543633
# host_listings_count                   -0.251724            0.033796
# host_identity_verified                 0.178139           -0.052880
# accommodates                           0.029976            0.027994
# neighbourhood_group_cleansed           0.018114           -0.041255
# property_type                          0.186267            0.012399
# room_type                             -0.050419           -0.016959
# latitude                               0.031472           -0.022824
# longitude                             -0.028175           -0.008856
# guests_included                        0.005917            0.034350
# bathrooms                             -0.051945           -0.008165
# bedrooms                               0.021130            0.000735
# beds                                   0.025615            0.014279
# bed_type                              -0.031330            0.018309
# amenities                              0.318589            0.099258
# cleaning_fee                          -0.038012            0.016047
# minimum_nights                        -0.048737           -0.038429
# maximum_nights                        -0.140728           -0.026918
# instant_bookable                      -0.108978            0.097616
# cancellation_policy                   -0.222283            0.024085
# price                                 -0.088158            0.014550
#
#                               host_response_time  host_listings_count  \
# host_is_superhost                       0.093204            -0.251724
# host_response_rate                      0.543633             0.033796
# host_response_time                      1.000000             0.116119
# host_listings_count                     0.116119             1.000000
# host_identity_verified                 -0.198366            -0.197717
# accommodates                            0.032403             0.012140
# neighbourhood_group_cleansed           -0.102309            -0.101225
# property_type                          -0.072047            -0.266301
# room_type                              -0.100374            -0.129484
# latitude                               -0.048493            -0.075716
# longitude                              -0.001172            -0.030291
# guests_included                         0.044858             0.044703
# bathrooms                              -0.084131             0.011453
# bedrooms                               -0.047909            -0.032705
# beds                                    0.000970            -0.037450
# bed_type                                0.055972             0.025270
# amenities                               0.084580            -0.086428
# cleaning_fee                            0.018739             0.135420
# minimum_nights                         -0.100741             0.006226
# maximum_nights                          0.008814             0.173826
# instant_bookable                        0.304955             0.165884
# cancellation_policy                     0.029392             0.206418
# price                                   0.041169             0.539016
#
#                               host_identity_verified  accommodates  \
# host_is_superhost                           0.178139      0.029976
# host_response_rate                         -0.052880      0.027994
# host_response_time                         -0.198366      0.032403
# host_listings_count                        -0.197717      0.012140
# host_identity_verified                      1.000000     -0.008747
# accommodates                               -0.008747      1.000000
# neighbourhood_group_cleansed                0.068154      0.038530
# property_type                               0.140287      0.109185
# room_type                                   0.117408     -0.379598
# latitude                                    0.049858     -0.024712
# longitude                                   0.009511     -0.054723
# guests_included                            -0.000534      0.665960
# bathrooms                                   0.048293      0.548977
# bedrooms                                    0.028514      0.812256
# beds                                        0.017903      0.865667
# bed_type                                   -0.078594      0.064678
# amenities                                   0.086255      0.247395
# cleaning_fee                               -0.076661      0.639728
# minimum_nights                              0.036959     -0.038819
# maximum_nights                             -0.059467      0.036861
# instant_bookable                           -0.293922      0.033269
# cancellation_policy                        -0.035471      0.204109
# price                                      -0.120693      0.499721
#
#                               neighbourhood_group_cleansed  property_type  \
# host_is_superhost                                 0.018114       0.186267
# host_response_rate                               -0.041255       0.012399
# host_response_time                               -0.102309      -0.072047
# host_listings_count                              -0.101225      -0.266301
# host_identity_verified                            0.068154       0.140287
# accommodates                                      0.038530       0.109185
# neighbourhood_group_cleansed                      1.000000       0.074479
# property_type                                     0.074479       1.000000
# room_type                                         0.027287       0.308465
# latitude                                          0.008727       0.012634
# longitude                                        -0.141724       0.002433
# guests_included                                   0.015412       0.069650
# bathrooms                                         0.047564       0.259222
# bedrooms                                          0.071119       0.242191
# beds                                              0.055181       0.142305
# bed_type                                         -0.015201      -0.030322
# amenities                                         0.078021       0.126330
# cleaning_fee                                      0.034962       0.040919
# minimum_nights                                    0.011145      -0.011895
# maximum_nights                                   -0.045686      -0.116503
# instant_bookable                                 -0.101991      -0.129392
# cancellation_policy                              -0.038583      -0.154268
# price                                            -0.035901      -0.091736
#
#                               room_type  latitude  ...  bedrooms      beds  \
# host_is_superhost             -0.050419  0.031472  ...  0.021130  0.025615
# host_response_rate            -0.016959 -0.022824  ...  0.000735  0.014279
# host_response_time            -0.100374 -0.048493  ... -0.047909  0.000970
# host_listings_count           -0.129484 -0.075716  ... -0.032705 -0.037450
# host_identity_verified         0.117408  0.049858  ...  0.028514  0.017903
# accommodates                  -0.379598 -0.024712  ...  0.812256  0.865667
# neighbourhood_group_cleansed   0.027287  0.008727  ...  0.071119  0.055181
# property_type                  0.308465  0.012634  ...  0.242191  0.142305
# room_type                      1.000000  0.039275  ... -0.177392 -0.260674
# latitude                       0.039275  1.000000  ... -0.011263 -0.005180
# longitude                      0.105326 -0.163524  ... -0.038281 -0.039856
# guests_included               -0.248937 -0.020540  ...  0.587819  0.581370
# bathrooms                      0.055332  0.007133  ...  0.613708  0.536232
# bedrooms                      -0.177392 -0.011263  ...  1.000000  0.753692
# beds                          -0.260674 -0.005180  ...  0.753692  1.000000
# bed_type                      -0.100198 -0.022499  ...  0.051466  0.048004
# amenities                     -0.195683 -0.030951  ...  0.192607  0.211537
# cleaning_fee                  -0.381087 -0.013978  ...  0.620596  0.552384
# minimum_nights                -0.031819  0.036532  ...  0.000170 -0.023865
# maximum_nights                -0.138066 -0.025317  ...  0.017022 -0.000738
# instant_bookable              -0.091306 -0.042532  ... -0.036526 -0.011008
# cancellation_policy           -0.104280 -0.017742  ...  0.155814  0.182790
# price                         -0.309817 -0.036569  ...  0.436939  0.426288
#
#                               bed_type  amenities  cleaning_fee  \
# host_is_superhost            -0.031330   0.318589     -0.038012
# host_response_rate            0.018309   0.099258      0.016047
# host_response_time            0.055972   0.084580      0.018739
# host_listings_count           0.025270  -0.086428      0.135420
# host_identity_verified       -0.078594   0.086255     -0.076661
# accommodates                  0.064678   0.247395      0.639728
# neighbourhood_group_cleansed -0.015201   0.078021      0.034962
# property_type                -0.030322   0.126330      0.040919
# room_type                    -0.100198  -0.195683     -0.381087
# latitude                     -0.022499  -0.030951     -0.013978
# longitude                    -0.019863  -0.096540     -0.100058
# guests_included               0.049835   0.167818      0.522198
# bathrooms                     0.036770   0.086271      0.488651
# bedrooms                      0.051466   0.192607      0.620596
# beds                          0.048004   0.211537      0.552384
# bed_type                      1.000000   0.010611      0.074258
# amenities                     0.010611   1.000000      0.157539
# cleaning_fee                  0.074258   0.157539      1.000000
# minimum_nights                0.015702  -0.034562      0.069021
# maximum_nights                0.035526  -0.071866      0.143213
# instant_bookable              0.032567  -0.034802      0.015757
# cancellation_policy           0.046131  -0.050170      0.370912
# price                         0.050733   0.095954      0.489470
#
#                               minimum_nights  maximum_nights  \
# host_is_superhost                  -0.048737       -0.140728
# host_response_rate                 -0.038429       -0.026918
# host_response_time                 -0.100741        0.008814
# host_listings_count                 0.006226        0.173826
# host_identity_verified              0.036959       -0.059467
# accommodates                       -0.038819        0.036861
# neighbourhood_group_cleansed        0.011145       -0.045686
# property_type                      -0.011895       -0.116503
# room_type                          -0.031819       -0.138066
# latitude                            0.036532       -0.025317
# longitude                          -0.007538        0.008247
# guests_included                    -0.030652        0.018778
# bathrooms                          -0.006655        0.013907
# bedrooms                            0.000170        0.017022
# beds                               -0.023865       -0.000738
# bed_type                            0.015702        0.035526
# amenities                          -0.034562       -0.071866
# cleaning_fee                        0.069021        0.143213
# minimum_nights                      1.000000        0.043840
# maximum_nights                      0.043840        1.000000
# instant_bookable                   -0.095543        0.089567
# cancellation_policy                 0.050013        0.047667
# price                              -0.022610        0.091178
#
#                               instant_bookable  cancellation_policy     price
# host_is_superhost                    -0.108978            -0.222283 -0.088158
# host_response_rate                    0.097616             0.024085  0.014550
# host_response_time                    0.304955             0.029392  0.041169
# host_listings_count                   0.165884             0.206418  0.539016
# host_identity_verified               -0.293922            -0.035471 -0.120693
# accommodates                          0.033269             0.204109  0.499721
# neighbourhood_group_cleansed         -0.101991            -0.038583 -0.035901
# property_type                        -0.129392            -0.154268 -0.091736
# room_type                            -0.091306            -0.104280 -0.309817
# latitude                             -0.042532            -0.017742 -0.036569
# longitude                             0.008736            -0.018249 -0.076728
# guests_included                       0.054904             0.191899  0.396957
# bathrooms                            -0.058729             0.175307  0.369484
# bedrooms                             -0.036526             0.155814  0.436939
# beds                                 -0.011008             0.182790  0.426288
# bed_type                              0.032567             0.046131  0.050733
# amenities                            -0.034802            -0.050170  0.095954
# cleaning_fee                          0.015757             0.370912  0.489470
# minimum_nights                       -0.095543             0.050013 -0.022610
# maximum_nights                        0.089567             0.047667  0.091178
# instant_bookable                      1.000000             0.008130  0.100893
# cancellation_policy                   0.008130             1.000000  0.253394
# price                                 0.100893             0.253394  1.000000
#
# [23 rows x 23 columns]

# %%
# Installing lazy predict on google collab. As lazy predict gives rough idea of the models and their respective accuracies. 
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading https://files.pythonhosted.org/packages/5f/db/1566dca1050ea74e9474dca0f1e7bbffcb0c3e694cf92e7e6e7ef9fca3af/lazypredict-0.2.7-py2.py3-none-any.whl
# Requirement already satisfied: Click>=7.0 in c:\users\jay dave\anaconda3\lib\site-packages (from lazypredict) (7.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.7

# %%
# Importing required libararies to train the model

import lazypredict
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-198-84a313147c86> in <module>
#       3 import lazypredict
#       4 from sklearn.model_selection import train_test_split
# ----> 5 from lazypredict.Supervised import LazyRegressor
#
# ~\Anaconda3\lib\site-packages\lazypredict\Supervised.py in <module>
#      27 pd.set_option("display.float_format", lambda x: '%.2f' % x)
#      28
# ---> 29 CLASSIFIERS = [est for est in all_estimators(
#      30 ) if issubclass(est[1], ClassifierMixin)]
#      31 REGRESSORS = [est for est in all_estimators(
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\testing.py in all_estimators(include_meta_estimators, include_other, type_filter, include_dont_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_dbscan.py in <module>
#      15
#      16 from ..base import BaseEstimator, ClusterMixin
# ---> 17 from ..utils.validation import _check_sample_weight, _deprecate_positional_args
#      18 from ..neighbors import NearestNeighbors
#      19
#
# ImportError: cannot import name '_check_sample_weight' from 'sklearn.utils.validation' (C:\Users\Jay Dave\Anaconda3\lib\site-packages\sklearn\utils\validation.py)
